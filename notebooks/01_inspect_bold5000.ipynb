# %% [markdown]
# # Inspect BOLD5000
#
# This lightweight notebook documents commands; run scripts for reproducible outputs.

# %%
from pathlib import Path
import pandas as pd
Path('../outputs').exists()
